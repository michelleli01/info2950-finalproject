# %% [markdown]
# ## INFO 2950 Final Project
# Larrisa Chen (lc949), Michelle Li (myl39), Christina Jin (cej65), Jade Eggleston (jce76)

# %% [markdown]
# ### Research question
# ***Do the criteria for a successful Airbnb differ in U.S. regions?***
#
# Where success is defined as:
# - high number of bookings combined with high listing rating
#
# and criteria is defined by:
# - Price
# - Number of Beds
# - Number of Baths
# - Host ratings
# - Number of reviews
# - Private or Public
# - Proximity to urban center (most popular neighborhood)
# - Neighborhood
# - Keywords in names
# - Keywords in description
# - Host response rate / time
# - Room type
# - Amenities (binary)
#     - varies by region
#
# The list of amenities is scraped from each of the cities listed below and aggregated to find the top 15 in each region.
#
# Ultimately, we want to deduce the attributes that contribute to a successful Airbnb listing and compare these listings across different regions in the U.S. (Northeast, Southeast, Southeast, West, Northwest, and Midwest).

# %% [markdown]
# ### Data Origin/Description
#
# Our data is sourced from http://insideairbnb.com/get-the-data/.
#
# We aggregated data from cities which receive the highest number of inbound tourism in each region from *link*.
# The cities being analyzed are as follows:
# - New England: Boston
# - Middle Atlantic: New York City
# - East North Central: Chicago
# - West North Central: Minneapolis
# - South Atlantic: Miami
# - East South Central: Nashville
# - West South Central: San Antonio
# - Mountain: Las Vegas
# - Pacific: Los Angeles
#
#
#
# For each city, we want to analyze:
# - Lisitng data with columns:
#     - id
#     - name
#     - description
#     - host_since
#     - host_about
#     - host_response_time
#     - host_response_rate
#     - host_acceptance_rate
#     - host_is_superhost
#     - host_listings_count
#     - host_has_profile_pic
#     - host_identity_verified
#     - neighbourhood_cleansed
#     - neighbourhood_group_cleansed
#     - room_type
#     - accommodates
#     - bathrooms_text
#     - bedrooms
#     - beds
#     - amenities
#     - price
#     - minimum_nights
#     - maximum_nights
#     - number_of_reviews
#     - last_review
#     - review_scores_rating
#     - instant_bookable
#
# - and booking data with columns:
#     - list columns here

# %% [markdown]
# ### Data Collection & Cleaning
#
# We begin by removing all rows which contain NaN, so that analyzation can take place where all columns are one type.
#
# Then, we analyze the columns and manually delete the following:
# - listing_url
#     - Repetitive data
# - Maximum_maximum_nights
#     - Repetitive data
# - Minimum_nights_avg_ntm
#     - Repetitive data
# - Maximum_nights_avg_ntm
#     - Repetitive data
# - Calendar_updated
#     - Only contains empty data
# - Has_availability
#     - All true, redundent
# - availability_30
#     - Assuming users only evaluate criteria for listings that are available
# - availability_60
#     - Assuming users only evaluate criteria for listings that are available
# - availability_90
#     - Assuming users only evaluate criteria for listings that are available
# - Availability_365
#     - Assuming users only evaluate criteria for listings that are available
# - calendar_last_scraped
# - Number_of_reviews_ltm
#     - Correlated to number_of_reviews, redundant
# - Number_of_reviews_l30d
#     - Correlated to number_of_reviews, redundant
# - First_review
#     - Redundant information because we have host_since
# - Review_scores_accuracy
#     - Correlated to review_scores_rating
# - Review_scores_cleanliness
#     - Correlated to review_scores_rating
# - Review_scores_checkin
#     - Correlated to review_scores_rating
# - Review_scores_communication
#     - Correlated to review_scores_rating
# - Review_scores_location
#     - Correlated to review_scores_rating
# - Review_scores_value
#     - Correlated to review_scores_rating
# - License
#     - Only contains empty data
# - calculated_host_listings_count
# - Calculated_host_listings_count_entire_homes
#     - Information about host’s other listings are not relevant to this listing
# - Calculated_host_listings_count_private_rooms
#     - Information about host’s other listings are not relevant to this listing
# - Calculated_host_listings_count_shared_rooms
#     - Information about host’s other listings are not relevant to this listing
# - Reviews_per_month
#     - Too dependent on other people’s stay time, irrelevant metric
# - Neighbourhood_group_cleansed
#     - Inconsistent across different cities
# - House_availability
#     - If listing is unavailable, users will not view it and it will by default not be the best listing

# %%
import numpy as np
import pandas as pd
import regex as re
import json

import ast
import seaborn as sns
import matplotlib.pyplot as plt

# %%
def percent_to_float(x):
    return float(x.strip("%"))/100.0

def dollar_to_float(x):
    x = x.replace(",", "")
    x = x.replace("$", "")
    return float(x)

def str_to_bool(x):
    if(x == "f"):
        return False
    else:
        return True
    
def room_type_to_bool(x):
    if(x == "Shared room"):
        return False
    return True

def bathrooms_text_to_bool(x):
    if(str(x).find("shared") != -1 or str(x).find("Shared") != -1):
        return False
    return True
    
def amenities_to_list(x):
    return json.loads(x)
    
def host_response_time_to_int(x):
    if(x == "within an hour"):
        return 0
    elif(x == "within a few hours"):
        return 1
    elif(x == "within a day"):
        return 2
    elif(x == "a few days or more"):
        return 3
    elif(x == "None"):
        return 4
    
def bathroom_text_to_float(x):
    if(x.find("half-bath") != -1 or x.find("Half-bath") != -1):
        return 0.5
    elif(re.search(r"d+\.\d+", x) != None):
        return float(re.search(r"d+\.\d+", x).group())
    return int(re.search(r"\d+", x).group())

def is_string(x):
    for letter in x:
        if((letter >= "A" and letter <= "Z") or (letter >= "a" and letter <="z") or (letter >= "0" and letter <= "9")):
            return True;
    return False;

nyc_listings_df = pd.read_csv("nyc_listings.csv")

nyc_listings_df = nyc_listings_df[nyc_listings_df["host_about"].notna()]
nyc_listings_df = nyc_listings_df[nyc_listings_df["host_response_time"].notna()]
nyc_listings_df = nyc_listings_df[nyc_listings_df["host_response_rate"].notna()]
nyc_listings_df = nyc_listings_df[nyc_listings_df["host_acceptance_rate"].notna()]
nyc_listings_df = nyc_listings_df[nyc_listings_df["last_review"].notna()]
nyc_listings_df = nyc_listings_df[nyc_listings_df["review_scores_rating"].notna()]
nyc_listings_df = nyc_listings_df[nyc_listings_df["description"].notna()]
nyc_listings_df = nyc_listings_df[nyc_listings_df["beds"].notna()]
nyc_listings_df = nyc_listings_df[nyc_listings_df["bedrooms"].notna()]
nyc_listings_df = nyc_listings_df[nyc_listings_df["bathrooms_text"].notna()]

nyc_listings_df = nyc_listings_df[nyc_listings_df["host_about"].apply(is_string)]
nyc_listings_df = nyc_listings_df[nyc_listings_df["name"].apply(is_string)]
nyc_listings_df = nyc_listings_df[nyc_listings_df["description"].apply(is_string)]

nyc_listings_df["host_response_rate"] = nyc_listings_df["host_response_rate"].apply(percent_to_float)
nyc_listings_df["host_acceptance_rate"] = nyc_listings_df["host_acceptance_rate"].apply(percent_to_float)
nyc_listings_df["price"] = nyc_listings_df["price"].apply(dollar_to_float)
nyc_listings_df["instant_bookable"] = nyc_listings_df["instant_bookable"].apply(str_to_bool)
nyc_listings_df["host_identity_verified"] = nyc_listings_df["host_identity_verified"].apply(str_to_bool)
nyc_listings_df["host_has_profile_pic"] = nyc_listings_df["host_has_profile_pic"].apply(str_to_bool)
nyc_listings_df["host_is_superhost"] = nyc_listings_df["host_is_superhost"].apply(str_to_bool)
nyc_listings_df["host_response_time"] = nyc_listings_df["host_response_time"].apply(host_response_time_to_int)
nyc_listings_df["amenities"] = nyc_listings_df["amenities"].apply(amenities_to_list)

nyc_listings_df = nyc_listings_df.rename(columns={"room_type": "is_private_room"})
nyc_listings_df["is_private_room"] = nyc_listings_df["is_private_room"].apply(room_type_to_bool)
nyc_listings_df["is_private_bath"] = nyc_listings_df["bathrooms_text"].apply(bathrooms_text_to_bool)
nyc_listings_df = nyc_listings_df.rename(columns={"bathrooms_text": "baths"})
nyc_listings_df["baths"] = nyc_listings_df["baths"].apply(bathroom_text_to_float)
nyc_listings_df["is_private_overall"] = nyc_listings_df["is_private_room"] & nyc_listings_df["is_private_bath"]

nyc_listings_df["host_since"] = pd.to_datetime(nyc_listings_df["host_since"])
nyc_listings_df["last_review"] = pd.to_datetime(nyc_listings_df["last_review"])

print(nyc_listings_df.dtypes)
print(nyc_listings_df.shape)
print(nyc_listings_df)

nyc_calendar_df = pd.read_csv("nyc_calendar.csv")
nyc_calendar_df = nyc_calendar_df.drop("price", axis=1)
nyc_calendar_df = nyc_calendar_df.drop("adjusted_price", axis=1)
nyc_calendar_df["date"] = pd.to_datetime(nyc_calendar_df["date"])
nyc_calendar_df["available"] = nyc_calendar_df["available"].apply(str_to_bool)

print(nyc_calendar_df)
print(nyc_calendar_df.dtypes)
# Out:
# id                               float64
# name                              object
# description                       object
# host_since                datetime64[ns]
# host_about                        object
# host_response_time                 int64
# host_response_rate               float64
# host_acceptance_rate             float64
# host_is_superhost                   bool
# host_listings_count              float64
# host_has_profile_pic                bool
# host_identity_verified              bool
# neighbourhood_cleansed            object
# is_private_room                     bool
# accommodates                       int64
# baths                            float64
# bedrooms                         float64
# beds                             float64
# amenities                         object
# price                            float64
# minimum_nights                     int64
# maximum_nights                     int64
# number_of_reviews                  int64
# last_review               datetime64[ns]
# review_scores_rating             float64
# instant_bookable                    bool
# is_private_bath                     bool
# is_private_overall                  bool
# dtype: object
# (11097, 28)
#                id                                              name  \
# 0          2539.0                Clean & quiet apt home by the park
# 3         45910.0                Beautiful Queens Brownstone! - 5BR
# 6         77765.0                              Superior @ Box House
# 7          5178.0                   Large Furnished Room Near B'way
# 8         80493.0                 Cozy room in East Village with AC
# ...           ...                                               ...
# 39860    696868.0       Studio Apartment close to Midtown Manhattan
# 39861   9023424.0   ELEGANT 3 BED MINS to Times Square NYC, Parking
# 39864  17662555.0  AMAZING CITY VIEWS 15 min Times Sq 30Day minimum
# 39868  26226078.0                           Your Home on the Hudson
# 39869  30085707.0      2BR Apartment with Patio, 10min to Manhattan
#
#                                              description host_since  \
# 0      Renovated apt home in elevator building.<br />... 2008-09-07
# 3      <b>The space</b><br />Beautiful, fully furnish... 2010-08-17
# 6      <b>The space</b><br />Charming standard queen ... 2011-03-01
# 7      Please don’t expect the luxury here just a bas... 2009-03-03
# 8      This room is up three flights of stairs - it's... 2011-03-10
# ...                                                  ...        ...
# 39860  The place is ideal for a person or a couple ne... 2012-09-14
# 39861  ENJOY YOUR NYC VACATION STAY IN AN ELEGANT 3 B... 2015-06-13
# 39864  Enjoy breathtaking views of the NYC skyline ov... 2014-10-30
# 39868  Spacious apartment with great view of New York... 2018-06-21
# 39869  Modern industrial style apartment in Jersey Ci... 2014-08-12
#
#                                               host_about  host_response_time  \
# 0      Educated professional living in Brooklyn.  I l...                   0
# 3                           Father of two boys - 9 & 10.                   0
# 6      Thank you for your interest in the Box House H...                   0
# 7      I used to work for a financial industry but no...                   1
# 8      I'm a New York based writer and singer who doe...                   0
# ...                                                  ...                 ...
# 39860  This is a family house on the first and second...                   1
# 39861  I am a finance professional with a passion for...                   1
# 39864      I'm a published poet, travel writer and ad...                   2
# 39868  I am in the fashion and textile industry and t...                   0
# 39869  I'm a postdoc working on cancer research. Just...                   0
#
#        host_response_rate  host_acceptance_rate  host_is_superhost  \
# 0                    1.00                  0.90              False
# 3                    1.00                  0.19              False
# 6                    0.99                  0.98               True
# 7                    1.00                  1.00              False
# 8                    1.00                  0.86              False
# ...                   ...                   ...                ...
# 39860                0.94                  0.87               True
# 39861                1.00                  0.96               True
# 39864                0.82                  0.52              False
# 39868                1.00                  0.92              False
# 39869                1.00                  0.92              False
#
#        host_listings_count  ...  \
# 0                      9.0  ...
# 3                      7.0  ...
# 6                     30.0  ...
# 7                      1.0  ...
# 8                      1.0  ...
# ...                    ...  ...
# 39860                  2.0  ...
# 39861                  3.0  ...
# 39864                  4.0  ...
# 39868                  3.0  ...
# 39869                  1.0  ...
#
#                                                amenities  price  \
# 0      [First aid kit, Microwave, Stove, Coffee maker...  299.0
# 3      [Hair dryer, Essentials, Carbon monoxide alarm...  425.0
# 6      [First aid kit, Coffee maker, Gym, Long term s...  308.0
# 7      [Body soap, Microwave, Laundromat nearby, Mini...   68.0
# 8      [Essentials, Oven, Cable TV, Refrigerator, Mic...   55.0
# ...                                                  ...    ...
# 39860  [First aid kit, Body soap, Microwave, Laundrom...   94.0
# 39861  [Microwave, Stove, Coffee maker, Long term sta...  200.0
# 39864  [Microwave, Stove, Coffee maker, Long term sta...  171.0
# 39868  [Microwave, Stove, Coffee maker, Long term sta...  199.0
# 39869  [Microwave, Stove, Coffee maker, Long term sta...  260.0
#
#       minimum_nights  maximum_nights  number_of_reviews  last_review  \
# 0                 30             730                  9   2018-10-19
# 3                 30             730                 13   2019-11-12
# 6                  2             365                 42   2022-07-18
# 7                  2              14                550   2022-08-22
# 8                  2              60                207   2022-08-13
# ...              ...             ...                ...          ...
# 39860              3              15                302   2022-08-23
# 39861              3            1125                123   2022-06-30
# 39864             30            1125                 65   2022-02-01
# 39868              5              60                 27   2022-07-16
# 39869             29            1125                147   2022-08-20
#
#        review_scores_rating  instant_bookable is_private_bath  \
# 0                      4.89             False           False
# 3                      4.42             False            True
# 6                      4.90             False            True
# 7                      4.23             False            True
# 8                      4.34             False           False
# ...                     ...               ...             ...
# 39860                  4.74             False            True
# 39861                  4.91             False            True
# 39864                  4.52             False            True
# 39868                  4.63             False            True
# 39869                  4.82             False            True
#
#        is_private_overall
# 0                   False
# 3                    True
# 6                    True
# 7                    True
# 8                   False
# ...                   ...
# 39860                True
# 39861                True
# 39864                True
# 39868                True
# 39869                True
#
# [11097 rows x 28 columns]
#                   listing_id       date  available  minimum_nights  \
# 0                       2539 2022-09-07      False            30.0
# 1                       2539 2022-09-08      False            30.0
# 2                       2539 2022-09-09      False            30.0
# 3                       2539 2022-09-10      False            30.0
# 4                       2539 2022-09-11      False            30.0
# ...                      ...        ...        ...             ...
# 14551457  709854858248316418 2023-09-02       True            30.0
# 14551458  709854858248316418 2023-09-03       True            30.0
# 14551459  709854858248316418 2023-09-04       True            30.0
# 14551460  709854858248316418 2023-09-05       True            30.0
# 14551461  709854858248316418 2023-09-06       True            30.0
#
#           maximum_nights
# 0                  730.0
# 1                  730.0
# 2                  730.0
# 3                  730.0
# 4                  730.0
# ...                  ...
# 14551457           365.0
# 14551458           365.0
# 14551459           365.0
# 14551460           365.0
# 14551461           365.0
#
# [14551462 rows x 5 columns]
# listing_id                 int64
# date              datetime64[ns]
# available                   bool
# minimum_nights           float64
# maximum_nights           float64
# dtype: object

# %%
# %load_ext sql

# %config SqlMagic.autopandas = True
# %config SqlMagic.feedback = False
# %config SqlMagic.displaycon = False

# %sql duckdb:///:memory:

# %%
# %sql nyc_bookings_df << (SELECT listing_id, COUNT(available) AS days_booked FROM nyc_calendar_df WHERE available = False GROUP BY listing_id)
# %sql nyc_combined_df << (SELECT * FROM nyc_listings_df LEFT JOIN nyc_bookings_df ON nyc_listings_df.id = nyc_bookings_df.listing_id)
# %sql nyc_listings_df << SELECT * FROM nyc_listings_df ORDER BY price 
# %sql nyc_combined_df << SELECT * FROM nyc_combined_df ORDER BY price 
# %sql nyc_price_reviews_df << SELECT AVG(price) as average_price, review_scores_rating FROM nyc_combined_df GROUP BY review_scores_rating ORDER BY review_scores_rating
# %sql nyc_review_booking_df << SELECT SUM(days_booked) AS total_days_booked, review_scores_rating FROM nyc_combined_df GROUP BY review_scores_rating
# %sql nyc_price_booking_df << SELECT days_booked, price FROM nyc_combined_df GROUP BY price, days_booked ORDER BY days_booked
# Out:
# Returning data to local variable nyc_bookings_df
# Returning data to local variable nyc_combined_df
# Returning data to local variable nyc_listings_df
# Returning data to local variable nyc_combined_df
# Returning data to local variable nyc_price_reviews_df
# Returning data to local variable nyc_review_booking_df

# %%
# %sql nyc_price_booking_df_1 << SELECT * FROM nyc_price_booking_df FETCH FIRST 4631 ROWS ONLY
# Out:
# Returning data to local variable nyc_price_booking_df_1

# %%
# %sql nyc_price_booking_df << SELECT days_booked, price FROM nyc_combined_df GROUP BY price, days_booked ORDER BY days_booked DESC
# %sql nyc_price_booking_df_2 << SELECT * FROM nyc_price_booking_df FETCH FIRST 4621 ROWS ONLY
# Out:
# Returning data to local variable nyc_price_booking_df
# Returning data to local variable nyc_price_booking_df_2

# %%
nyc_combined_df = nyc_combined_df.drop(columns = 'listing_id')
nyc_listings_df = nyc_listings_df.drop([11094, 11095, 11096])
nyc_combined_df = nyc_combined_df.drop([11094, 11095, 11096])

# %% [markdown]
# #### NYC Amenity Scraping

# %%
nyc_amenities_df = pd.DataFrame(nyc_combined_df['amenities'])
nyc_amenities_list_accum = []
df_len = len(nyc_amenities_df.index)
for i in range(0,df_len):
    x = ast.literal_eval(nyc_amenities_df.iloc[i, 0])
    nyc_amenities_list_accum.append(x)
    i+=1

# %%
nyc_amenities_frequency={}
for list in nyc_amenities_list_accum:
    for item in list:
        if item in nyc_amenities_frequency:
            nyc_amenities_frequency[item] += 1
        else:
            nyc_amenities_frequency[item] = 1

# %%
nyc_amenities_df = pd.DataFrame(nyc_amenities_frequency, index=[0])
nyc_amenities_list = nyc_amenities_df.columns

# %%
nyc_amenities_df = pd.melt(nyc_amenities_df, value_vars=nyc_amenities_list, value_name='amenity_count')

# %%
# %sql nyc_amenities_df << SELECT * FROM nyc_amenities_df ORDER BY amenity_count DESC FETCH FIRST 30 ROWS ONLY;
# Out:
# Returning data to local variable nyc_amenities_df

# %%
nyc_amenities_df
# Out:
#                       variable  amenity_count
# 0                  Smoke alarm          10555
# 1                   Essentials          10143
# 2                         Wifi           9964
# 3                      Kitchen           9778
# 4      Long term stays allowed           9715
# 5        Carbon monoxide alarm           9687
# 6                      Hangers           9498
# 7                    Hot water           9273
# 8                   Hair dryer           8944
# 9                         Iron           8799
# 10       Dishes and silverware           8757
# 11                Refrigerator           8387
# 12                     Heating           8359
# 13              Cooking basics           8017
# 14                   Microwave           7456
# 15                Coffee maker           7406
# 16                     Shampoo           7337
# 17                  Bed linens           7312
# 18            Air conditioning           6832
# 19         Free street parking           6718
# 20           Fire extinguisher           6454
# 21                        Oven           5712
# 22         Dedicated workspace           5695
# 23                       Stove           5679
# 24               First aid kit           5605
# 25  Extra pillows and blankets           5200
# 26                     Bathtub           4305
# 27           Cleaning products           4302
# 28                          TV           4187
# 29                     Freezer           4016

# %% [markdown]
# ### Data Limitations

# %% [markdown]
# ### Exploratory Data Analysis

# %%
import numpy as np
import seaborn as sns
import pandas as pd

import matplotlib.pyplot as plt

# %%
# %sql SELECT * FROM nyc_listings_df WHERE review_scores_rating IS NOT NULL ORDER BY review_scores_rating ASC
# Out:
#                  id                                               name  \
# 0      3.388395e+07                         New Building Room 6 from 1
# 1      3.515857e+07  Modern, Peaceful Room In Lively East Williamsb...
# 2      1.597414e+07                                               100$
# 3      2.758348e+07                                        River View!
# 4      3.292336e+07       Guest Room in a Warm, friendly Artist's Home
# ...             ...                                                ...
# 11089  6.331134e+17  HISTORIC $10MLN MANSION IN THE HEART OF PARK S...
# 11090  1.440811e+07           Unparalleled Luxury in Midtown Manhattan
# 11091  3.448529e+07  Horizon Suite w/ sofa bed, your sanctuary in SoHo
# 11092  1.585726e+07        5 Star Luxury 2 BR Suite Heart of Manhattan
# 11093  3.101962e+07  Luxury on 5th Ave St. Regis 2 King BR Suite 5 ...
#
#                                              description host_since  \
# 0      CLEAN, NEW ROOMS (BRAND NEW HOUSE):<br />Acces... 2018-07-18
# 1      Sitting right on bustling Grand St in the up-a... 2016-02-17
# 2      I am renting my super cozy and very spacious 1... 2015-09-29
# 3      Spacious, neat, beautiful, and quiet one-bedro... 2013-01-02
# 4      Beautiful Artist's apartment situated on a tre... 2014-01-04
# ...                                                  ...        ...
# 11089  ECCENTRIC SOPHISTICATED 18TH CENTURY MANSION<b... 2012-08-29
# 11090  Boasting unparalleled luxury, this one-bedroom... 2011-07-18
# 11091  The Horizon Suite can accommodate up to four p... 2019-05-09
# 11092  Experience unparalleled luxury at the iconic S... 2015-01-22
# 11093  Experience unparalleled luxury at the iconic S... 2015-01-22
#
#                                               host_about  host_response_time  \
# 0      Cool, calm and collected!! ......" I go out of...                   0
# 1      We are a privately-held, US-base technology co...                   0
# 2      A happy Brazilian girl leaving in the capitol ...                   2
# 3                                       cool easy going,                   1
# 4      making my way around the world, sprinkling lov...                   3
# ...                                                  ...                 ...
# 11089  Dear Travelers,\n\nWelcome to our exclusive co...                   1
# 11090  Henry prides himself on offering superb accomm...                   0
# 11091  Welcome to 27 Grand Street Hotel\n\n27 Grand S...                   1
# 11092  We're Alyssa and Justin. We love to travel wit...                   0
# 11093  We're Alyssa and Justin. We love to travel wit...                   0
#
#        host_response_rate  host_acceptance_rate  host_is_superhost  \
# 0                    0.90                  0.88              False
# 1                    1.00                  1.00              False
# 2                    1.00                  0.67              False
# 3                    1.00                  0.00              False
# 4                    0.00                  0.00              False
# ...                   ...                   ...                ...
# 11089                0.93                  0.53               True
# 11090                1.00                  1.00              False
# 11091                1.00                  0.88              False
# 11092                1.00                  0.29               True
# 11093                1.00                  0.29               True
#
#        host_listings_count  ...  \
# 0                      6.0  ...
# 1                      2.0  ...
# 2                      1.0  ...
# 3                      1.0  ...
# 4                      1.0  ...
# ...                    ...  ...
# 11089                 27.0  ...
# 11090                 14.0  ...
# 11091                  2.0  ...
# 11092                  6.0  ...
# 11093                  6.0  ...
#
#                                                amenities   price  \
# 0      ['First aid kit', 'Coffee maker', 'Long term s...    55.0
# 1      ['Essentials', 'Central air conditioning', 'El...    60.0
# 2      ['Hair dryer', 'Essentials', 'Hot water', 'Hea...   100.0
# 3      ['Hair dryer', 'Essentials', 'Iron', 'Dishes a...   120.0
# 4      ['Hair dryer', 'Essentials', 'Iron', 'Heating'...   155.0
# ...                                                  ...     ...
# 11089  ['Microwave', 'Indoor fireplace', 'Stove', 'Co...  2400.0
# 11090  ['Gym', 'Children’s dinnerware', 'Long term st...  2500.0
# 11091  ['Le Labo body soap', 'Coffee maker', 'Gym', '...  2500.0
# 11092  ['First aid kit', 'Microwave', 'Indoor firepla...  2799.0
# 11093  ['First aid kit', 'Gym', 'Long term stays allo...  2799.0
#
#       minimum_nights  maximum_nights  number_of_reviews  last_review  \
# 0                 15            1125                  2   2019-07-26
# 1                 30             150                  2   2020-03-10
# 2                 30              30                  1   2018-01-07
# 3                 30             120                  1   2018-08-08
# 4                 30            1125                  1   2019-09-17
# ...              ...             ...                ...          ...
# 11089              3             365                  1   2022-05-28
# 11090             30            1125                  4   2017-04-17
# 11091              1              28                  2   2021-07-11
# 11092              2              90                  9   2022-06-14
# 11093              2             112                  5   2021-12-26
#
#        review_scores_rating  instant_bookable is_private_bath  \
# 0                       0.0              True           False
# 1                       0.0              True           False
# 2                       0.0             False           False
# 3                       0.0             False            True
# 4                       0.0             False           False
# ...                     ...               ...             ...
# 11089                   5.0             False            True
# 11090                   5.0             False            True
# 11091                   5.0              True            True
# 11092                   5.0             False            True
# 11093                   5.0             False            True
#
#        is_private_overall
# 0                   False
# 1                   False
# 2                   False
# 3                    True
# 4                   False
# ...                   ...
# 11089                True
# 11090                True
# 11091                True
# 11092                True
# 11093                True
#
# [11094 rows x 28 columns]

# %%
nyc_calendar_df.head()
# Out:
#    listing_id       date  available  minimum_nights  maximum_nights
# 0        2539 2022-09-07      False            30.0           730.0
# 1        2539 2022-09-08      False            30.0           730.0
# 2        2539 2022-09-09      False            30.0           730.0
# 3        2539 2022-09-10      False            30.0           730.0
# 4        2539 2022-09-11      False            30.0           730.0

# %%
# %sql SELECT listing_id, COUNT(available) AS days_booked FROM nyc_calendar_df WHERE available = False GROUP BY listing_id ORDER BY days_booked DESC
# Out:
#                listing_id  days_booked
# 0                   64015          366
# 1                   18961          365
# 2                   20913          365
# 3                   25696          365
# 4                  597624          365
# ...                   ...          ...
# 39075  649239582021639044            1
# 39076            15495642            1
# 39077  547998622525410778            1
# 39078            36907176            1
# 39079            22292865            1
#
# [39080 rows x 2 columns]

# %% [markdown]
# ### Questions for Reviewers

# %% [markdown]
# ### Data Limitations

# %% [markdown]
# ### Exploratory Data Analysis

# %%
# %sql SELECT * FROM nyc_listings_df WHERE review_scores_rating IS NOT NULL ORDER BY review_scores_rating ASC
# Out:
#                  id                                               name  \
# 0      3.388395e+07                         New Building Room 6 from 1
# 1      3.515857e+07  Modern, Peaceful Room In Lively East Williamsb...
# 2      1.597414e+07                                               100$
# 3      2.758348e+07                                        River View!
# 4      3.292336e+07       Guest Room in a Warm, friendly Artist's Home
# ...             ...                                                ...
# 11089  6.331134e+17  HISTORIC $10MLN MANSION IN THE HEART OF PARK S...
# 11090  1.440811e+07           Unparalleled Luxury in Midtown Manhattan
# 11091  3.448529e+07  Horizon Suite w/ sofa bed, your sanctuary in SoHo
# 11092  1.585726e+07        5 Star Luxury 2 BR Suite Heart of Manhattan
# 11093  3.101962e+07  Luxury on 5th Ave St. Regis 2 King BR Suite 5 ...
#
#                                              description host_since  \
# 0      CLEAN, NEW ROOMS (BRAND NEW HOUSE):<br />Acces... 2018-07-18
# 1      Sitting right on bustling Grand St in the up-a... 2016-02-17
# 2      I am renting my super cozy and very spacious 1... 2015-09-29
# 3      Spacious, neat, beautiful, and quiet one-bedro... 2013-01-02
# 4      Beautiful Artist's apartment situated on a tre... 2014-01-04
# ...                                                  ...        ...
# 11089  ECCENTRIC SOPHISTICATED 18TH CENTURY MANSION<b... 2012-08-29
# 11090  Boasting unparalleled luxury, this one-bedroom... 2011-07-18
# 11091  The Horizon Suite can accommodate up to four p... 2019-05-09
# 11092  Experience unparalleled luxury at the iconic S... 2015-01-22
# 11093  Experience unparalleled luxury at the iconic S... 2015-01-22
#
#                                               host_about  host_response_time  \
# 0      Cool, calm and collected!! ......" I go out of...                   0
# 1      We are a privately-held, US-base technology co...                   0
# 2      A happy Brazilian girl leaving in the capitol ...                   2
# 3                                       cool easy going,                   1
# 4      making my way around the world, sprinkling lov...                   3
# ...                                                  ...                 ...
# 11089  Dear Travelers,\n\nWelcome to our exclusive co...                   1
# 11090  Henry prides himself on offering superb accomm...                   0
# 11091  Welcome to 27 Grand Street Hotel\n\n27 Grand S...                   1
# 11092  We're Alyssa and Justin. We love to travel wit...                   0
# 11093  We're Alyssa and Justin. We love to travel wit...                   0
#
#        host_response_rate  host_acceptance_rate  host_is_superhost  \
# 0                    0.90                  0.88              False
# 1                    1.00                  1.00              False
# 2                    1.00                  0.67              False
# 3                    1.00                  0.00              False
# 4                    0.00                  0.00              False
# ...                   ...                   ...                ...
# 11089                0.93                  0.53               True
# 11090                1.00                  1.00              False
# 11091                1.00                  0.88              False
# 11092                1.00                  0.29               True
# 11093                1.00                  0.29               True
#
#        host_listings_count  ...  \
# 0                      6.0  ...
# 1                      2.0  ...
# 2                      1.0  ...
# 3                      1.0  ...
# 4                      1.0  ...
# ...                    ...  ...
# 11089                 27.0  ...
# 11090                 14.0  ...
# 11091                  2.0  ...
# 11092                  6.0  ...
# 11093                  6.0  ...
#
#                                                amenities   price  \
# 0      ['First aid kit', 'Coffee maker', 'Long term s...    55.0
# 1      ['Essentials', 'Central air conditioning', 'El...    60.0
# 2      ['Hair dryer', 'Essentials', 'Hot water', 'Hea...   100.0
# 3      ['Hair dryer', 'Essentials', 'Iron', 'Dishes a...   120.0
# 4      ['Hair dryer', 'Essentials', 'Iron', 'Heating'...   155.0
# ...                                                  ...     ...
# 11089  ['Microwave', 'Indoor fireplace', 'Stove', 'Co...  2400.0
# 11090  ['Gym', 'Children’s dinnerware', 'Long term st...  2500.0
# 11091  ['Le Labo body soap', 'Coffee maker', 'Gym', '...  2500.0
# 11092  ['First aid kit', 'Microwave', 'Indoor firepla...  2799.0
# 11093  ['First aid kit', 'Gym', 'Long term stays allo...  2799.0
#
#       minimum_nights  maximum_nights  number_of_reviews  last_review  \
# 0                 15            1125                  2   2019-07-26
# 1                 30             150                  2   2020-03-10
# 2                 30              30                  1   2018-01-07
# 3                 30             120                  1   2018-08-08
# 4                 30            1125                  1   2019-09-17
# ...              ...             ...                ...          ...
# 11089              3             365                  1   2022-05-28
# 11090             30            1125                  4   2017-04-17
# 11091              1              28                  2   2021-07-11
# 11092              2              90                  9   2022-06-14
# 11093              2             112                  5   2021-12-26
#
#        review_scores_rating  instant_bookable is_private_bath  \
# 0                       0.0              True           False
# 1                       0.0              True           False
# 2                       0.0             False           False
# 3                       0.0             False            True
# 4                       0.0             False           False
# ...                     ...               ...             ...
# 11089                   5.0             False            True
# 11090                   5.0             False            True
# 11091                   5.0              True            True
# 11092                   5.0             False            True
# 11093                   5.0             False            True
#
#        is_private_overall
# 0                   False
# 1                   False
# 2                   False
# 3                    True
# 4                   False
# ...                   ...
# 11089                True
# 11090                True
# 11091                True
# 11092                True
# 11093                True
#
# [11094 rows x 28 columns]

# %%
# %sql SELECT listing_id, COUNT(available) AS days_booked FROM nyc_calendar_df WHERE available = 'f' GROUP BY listing_id ORDER BY days_booked DESC
# Out:
#                listing_id  days_booked
# 0                   64015          366
# 1                 1197899          365
# 2                 1198874          365
# 3                 1291245          365
# 4                 1312228          365
# ...                   ...          ...
# 39075  624508295836821889            1
# 39076             1755844            1
# 39077            10384214            1
# 39078  605721169816342867            1
# 39079  649239582021639044            1
#
# [39080 rows x 2 columns]

# %%
#%sql nyc_amenities_df << SELECT * FROM nyc_amenities_df ORDER BY

# %%
#x: price, y: reviews
fig, ax = plt.subplots(figsize=(30, 10))
sns.scatterplot(data=nyc_listings_df, x=nyc_listings_df["price"], y=nyc_listings_df["review_scores_rating"])
#plt.xticks(rotation=60)
plt.show()

# %%
#x: reviews, y: price
#sns.scatterplot(data=nyc_listings_df, x=nyc_listings_df["review_scores_rating"], y=nyc_listings_df["price"])
#the outlier is crazy i think we need to remove it (id = 11153)

# %%
#df = nyc_listings_df
#hist = df.hist(column='review_scores_rating')

# %%
#sns.scatterplot(data=nyc_listings_df, x=nyc_listings_df["review_scores_rating"], y=nyc_listings_df["price"])

# %%
#sns.scatterplot(data=nyc_combined_df, x=nyc_combined_df["price"], y=nyc_combined_df["days_booked"])

# %%
fig, ax = plt.subplots(figsize=(20, 10))
sns.barplot(data=nyc_price_reviews_df, x="review_scores_rating", y="average_price", ax = ax)
plt.xticks(rotation=60)
plt.show()

# %%
#split up
fig, ax = plt.subplots(figsize=(50, 10))
sns.barplot(data=nyc_price_booking_df_1, x="days_booked", y="price", ci=None, ax = ax)
plt.xticks(rotation=60)
plt.yticks(rotation=60)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(50, 10))
sns.barplot(data=nyc_price_booking_df_2, x="days_booked", y="price", ci = None, ax = ax)
plt.xticks(rotation=60)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(50, 10))
sns.barplot(data=nyc_review_booking_df, x="total_days_booked", y="review_scores_rating", ax = ax)
plt.xticks(rotation=60)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(20, 10))
sns.barplot(data=nyc_amenities_df, x="variable", y="amenity_count", ax = ax)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Questions for Reviewers
